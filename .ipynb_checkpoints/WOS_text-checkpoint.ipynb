# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
sn_path = "Social Networks/WOS data/"
ns_path = "Network Science/WOS data/"
jcn_path = "Journal of Complex Networks/WOS data/"

# %%
for file in os.listdir(sn_path):
    if file.endswith(".txt"):
        f = open(sn_path+file, "r", encoding="utf-8")
        sn_lines = f.readlines()
sn_lines
# Out:
# ['\ufeffFN Clarivate Analytics Web of Science\n',
#  'VR 1.0\n',
#  'PT J\n',
#  'AU Floyd, TM\n',
#  '   Gerbasi, A\n',
#  '   Labianca, G\n',
#  'AF Floyd, Theresa M.\n',
#  '   Gerbasi, Alexandra\n',
#  '   Labianca, Giuseppe (Joe)\n',
#  'TI The role of sociopolitical workplace networks in involuntary employee\n',
#  '   turnover\n',
#  'SO SOCIAL NETWORKS\n',
#  'LA English\n',
#  'DT Article\n',
#  'DE Involuntary turnover; Social networks; Sociopolitical context;\n',
#  '   Power-dependence theory; Political dependence\n',
#  'ID LEADER-MEMBER EXCHANGE; JOB-PERFORMANCE; SOCIAL NETWORKS; NEGATIVE TIES;\n',
#  '   VOLUNTARY TURNOVER; WORK; DETERMINANTS; SATISFACTION; DEPENDENCE; IMPACT\n',
# ...
